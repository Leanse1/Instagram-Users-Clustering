# %% [markdown]
# # K-means clustering in Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 01: importing the dataset

# %% [markdown]
# #### https://www.kaggle.com/chaandsheikh/instagram-visit-clustering

# %%
data = pd.read_csv('Instagram visits clustering.csv')

# %%
data.head(20)
# Out:
#     User ID  Instagram visit score  Spending_rank(0 to 100)
# 0         0                     63                24.050708
# 1         1                     61                25.223290
# 2         2                    104                18.528245
# 3         3                     82                86.890232
# 4         4                     14                31.492397
# 5         5                     74                81.195314
# 6         6                     83                88.119729
# 7         7                     71                87.468356
# 8         8                     42                80.829564
# 9         9                     79                25.966622
# 10       10                     94                24.465674
# 11       11                     30                30.975041
# 12       12                     62                23.936884
# 13       13                     19                14.216564
# 14       14                     36                23.461313
# 15       15                     17                22.405137
# 16       16                     98                14.599989
# 17       17                     87                12.504275
# 18       18                     55                11.760720
# 19       19                     65                 8.782404

# %%
data = data.sample(frac = 1)

# %% [markdown]
# ## Step 02: Extraction of data

# %%
X = data.iloc[:, [1, 2]].values

# %%
X[:10]
# Out:
# array([[ 84.        ,  20.80639274],
#        [ 23.        ,  33.52668522],
#        [ 80.        ,  23.85503135],
#        [ 91.        ,  82.93668457],
#        [ 95.        ,  26.96858861],
#        [ 87.        ,  17.47794606],
#        [ 34.        ,  60.61421798],
#        [ 77.        ,  23.22784164],
#        [104.        ,  18.52824526],
#        [ 70.        ,  23.13798508]])

# %% [markdown]
# # Step 03: Use elbow method for finding optimal number of clusters

# %%
conda install -c districtdatalabs yellowbrick
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Vincent\anaconda3
#
#   added / updated specs:
#     - yellowbrick
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       haa95532_0         123 KB
#     conda-content-trust-0.2.0  |  py311haa95532_0          82 KB
#     openssl-1.1.1w             |       h2bbff1b_0         5.5 MB
#     yellowbrick-1.5            |  py311haa95532_0         353 KB
#     ------------------------------------------------------------
#                                            Total:         6.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   imbalanced-learn   pkgs/main/win-64::imbalanced-learn-0.10.1-py311haa95532_1
#   scikit-learn       pkgs/main/win-64::scikit-learn-1.3.0-py311hf62ec03_0
#   yellowbrick        pkgs/main/win-64::yellowbrick-1.5-py311haa95532_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.05.30-haa95532_0 --> 2023.08.22-haa95532_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust~ --> pkgs/main/win-64::conda-content-trust-0.2.0-py311haa95532_0
#   openssl                                 1.1.1u-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# conda-content-trust- | 82 KB     |            |   0%
#
# ca-certificates-2023 | 123 KB    |            |   0%
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
#
# yellowbrick-1.5      | 353 KB    |            |   0%
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
# conda-content-trust- | 82 KB     | #9         |  20%
#
# ca-certificates-2023 | 123 KB    | #2         |  13%
#
#
# openssl-1.1.1w       | 5.5 MB    | 6          |   7%
#
#
# openssl-1.1.1w       | 5.5 MB    | #9         |  20%
#
# ca-certificates-2023 | 123 KB    | ########## | 100%
#
# ca-certificates-2023 | 123 KB    | ########## | 100%
# conda-content-trust- | 82 KB     | ########## | 100%
# conda-content-trust- | 82 KB     | ########## | 100%
#
#
# openssl-1.1.1w       | 5.5 MB    | ###        |  31%
#
#
#
# yellowbrick-1.5      | 353 KB    | 4          |   5%
#
#
# openssl-1.1.1w       | 5.5 MB    | ###9       |  40%
#
#
#
# yellowbrick-1.5      | 353 KB    | ###6       |  36%
#
#
# openssl-1.1.1w       | 5.5 MB    | #####2     |  53%
#
#
#
# yellowbrick-1.5      | 353 KB    | ######3    |  63%
#
#
# openssl-1.1.1w       | 5.5 MB    | ######6    |  67%
#
#
# openssl-1.1.1w       | 5.5 MB    | #######8   |  78%
#
#
# openssl-1.1.1w       | 5.5 MB    | ########9  |  89%
#
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
# yellowbrick-1.5      | 353 KB    | ########## | 100%
#
#
#
# yellowbrick-1.5      | 353 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/win-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/msys2/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/win-64/current_repodata.json HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /districtdatalabs/win-64/current_repodata.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /districtdatalabs/noarch/current_repodata.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /districtdatalabs/win-64/repodata.json HTTP/1.1" 200 2562
# DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /districtdatalabs/noarch/repodata.json HTTP/1.1" 200 None
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda-navigator==2.4.2=py311haa95532_0
#   - defaults/noarch::conda-content-trust==0.1.1=pyhd3eb1b0_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/win-64::scikit-learn-intelex==2023.1.1=py311haa95532_0
#   - defaults/win-64::_anaconda_depends==2023.07=py311_1
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.2
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0
#
#
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/openssl-1.1.1w-h2bbff1b_0.conda HTTP/1.1" 200 5763830
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/conda-content-trust-0.2.0-py311haa95532_0.conda HTTP/1.1" 200 83597
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/ca-certificates-2023.08.22-haa95532_0.conda HTTP/1.1" 200 126244
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/win-64/yellowbrick-1.5-py311haa95532_0.conda HTTP/1.1" 200 361727

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from yellowbrick.cluster import KElbowVisualizer

# %%
# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Vincent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ## Step 04: Apply K-means clustering

# %%
kmeans = KMeans(n_clusters=4, n_init = 10, random_state=0).fit(X)

# %%
kmeans.labels_
# Out:
# array([1, 3, 1, ..., 3, 1, 0])

# %%
y = kmeans.predict(X)

# %%
y[:200]
# Out:
# array([1, 3, 1, 2, 1, 1, 0, 1, 1, 1, 1, 2, 0, 1, 3, 1, 0, 1, 1, 2, 0, 0,
#        3, 1, 2, 1, 1, 2, 1, 2, 1, 3, 2, 3, 3, 1, 3, 2, 3, 3, 2, 1, 2, 0,
#        3, 2, 1, 3, 2, 2, 0, 3, 2, 1, 1, 1, 3, 1, 1, 3, 0, 0, 1, 1, 2, 1,
#        3, 3, 0, 3, 0, 0, 0, 3, 3, 0, 3, 0, 2, 0, 1, 1, 3, 2, 1, 2, 3, 1,
#        1, 3, 1, 2, 3, 3, 1, 1, 1, 3, 3, 0, 0, 0, 1, 1, 1, 2, 3, 2, 2, 1,
#        1, 0, 3, 3, 3, 1, 1, 0, 3, 0, 2, 0, 3, 3, 2, 3, 3, 1, 1, 1, 1, 2,
#        1, 1, 3, 1, 1, 1, 1, 1, 2, 1, 1, 3, 0, 1, 3, 3, 2, 3, 3, 3, 1, 1,
#        1, 1, 2, 3, 1, 0, 3, 0, 1, 1, 1, 2, 2, 0, 1, 2, 1, 3, 1, 2, 2, 3,
#        2, 3, 3, 3, 1, 2, 1, 1, 2, 2, 1, 3, 1, 0, 2, 3, 0, 1, 2, 1, 1, 3,
#        1, 0])

# %% [markdown]
# ## Step 05: Visualization

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='blue', label='Cluster 0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], c='red', label='Cluster 1')
plt.scatter(X[y == 2, 0], X[y == 2, 1], c='pink', label='Cluster 2')
plt.scatter(X[y == 3, 0], X[y == 3, 1], c='black', label='Cluster 3')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], c='green', label='Centers')
plt.xlabel('Instagram visit score')
plt.ylabel('Spending_rank(0 to 100)')
plt.legend()
plt.show()

# %% [markdown]
# # Extracting the cluster data

# %%
data.iloc[y == 3]
# Out:
#       User ID  Instagram visit score  Spending_rank(0 to 100)
# 2407     2407                     23                33.526685
# 1645     1645                     19                25.238729
# 1641     1641                      5                29.902139
# 994       994                     15                10.235315
# 413       413                     32                41.806699
# ...       ...                    ...                      ...
# 787       787                     27                23.915749
# 690       690                     11                27.277029
# 2050     2050                     32                25.656634
# 1767     1767                     31                23.129061
# 283       283                     52                13.571914
#
# [573 rows x 3 columns]

# %% [markdown]
# # Dendrogram

# %% [markdown]
# Clusters that merge at a lower height are more similar to each other, while clusters merging at a greater height are less similar.

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(10,10))
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Instagram visit score')
plt.ylabel('Spending_rank(0 to 100)')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 3, metric = 'euclidean', linkage = 'ward')
y = hc.fit_predict(X)

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1], c='blue', label='Cluster 0')
plt.scatter(X[y == 1, 0], X[y == 1, 1], c='red', label='Cluster 1')
plt.scatter(X[y == 2, 0], X[y == 2, 1], c='pink', label='Cluster 2')
plt.xlabel('Instagram visit score')
plt.ylabel('Spending_rank(0 to 100)')
plt.legend()
plt.show()
